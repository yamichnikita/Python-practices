# %% [markdown]
# Lists, tuples and sets are built-in data types in Python used to store multiple items in a single variable.
#
# List items are ordered, changeable, and allow duplicate values.
#
# Tuple items are ordered, unchangeable (we can't add or remove items), and allow duplicate values.
#
# A set is a collection which is unordered, unchangeable, and unindexed.

# %%
a = ['a', 12, 'dfsdf', 45.3]
type(a)
# Out:
# list

# %%
a = ('a', 12, 'dfsdf', 45.3)
type(a)
# Out:
# tuple

# %%
a = {'a', 12, 'dfsdf', 45.3}
type(a)
# Out:
# set

# %% [markdown]
# ![Снимок3.PNG](data:image/png;base64,...)

# %% [markdown]
# **List vs Set**

# %% [markdown]
# We can create a list or set based on the characters in a string. The functions to use are the list and set functions.

# %%
text = "Hello World!"
print(list(text))
print(set(text))
# Out:
# ['H', 'e', 'l', 'l', 'o', ' ', 'W', 'o', 'r', 'l', 'd', '!']
# {'r', '!', 'W', ' ', 'd', 'e', 'H', 'l', 'o'}

# %% [markdown]
# The differences in the resulting list and set objects:
#
# 1)The list contains all the characters whereas the set only contains unique characters.
#
# 2)The list is ordered based on the order of the characters in the string. There is no order associated with the items in the set.

# %% [markdown]
# **List vs Set — indexing**

# %% [markdown]
# In the previous example, we saw that sets do not possess an order. Thus, we cannot do slicing or indexing on sets like we do with lists.

# %%
text = "Hello World!"
list_a = list(text)
print(list_a[:2])
# Out:
# ['H', 'e']

# %%
set_a = set(text)
print(set_a[:2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-0a5370aeeaf5> in <module>
#       1 set_a = set(text)
# ----> 2 print(set_a[:2])
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# Slicing or indexing on sets raise a TypeError because it is an issue related to a property of set object type.

# %% [markdown]
# **List vs Tuple**

# %% [markdown]
# The difference between list and tuple is the mutability. Unlike lists, tuples are immutable. For instance, we can add items to a list but cannot do it with tuples.

# %%
list_a = [1,2,3,4]
list_a.append(5)
print(list_a)
# Out:
# [1, 2, 3, 4, 5]

# %%
tuple_a = (1,2,3,4)
tuple_a.append(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-4729c49b261d> in <module>
#       1 tuple_a = (1,2,3,4)
# ----> 2 tuple_a.append(5)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %% [markdown]
# The functions that changes a collection (e.g. append, remove, extend, pop) are not applicable to tuples.

# %% [markdown]
# **Tuple — mutable elements**

# %% [markdown]
# The immutability might be the most identifying feature of tuples. We cannot assign to the individual items of a tuple.

# %%
tuple_a = (3, 5, 'x', 5)
tuple_a[0] = 7 #error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-044f6625c9ca> in <module>
#       1 tuple_a = (3, 5, 'x', 5)
# ----> 2 tuple_a[0] = 7 #error
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# Although tuples are immutable, they can contain mutable elements such as lists or sets.

# %%
tuple_a = ([1,3], 'a', 'b', 8)
tuple_a[0][0] = 99
print(tuple_a)
# Out:
# ([99, 3], 'a', 'b', 8)

# %% [markdown]
# **List or Set or Tuple**

# %% [markdown]
# These collection objects can be converted from one to another. The functions to use are, as the names suggest, list, tuple, and set.

# %%
a = [1,2,3,'a',1,3,5]
print(tuple(a))
# Out:
# (1, 2, 3, 'a', 1, 3, 5)

# %%
print(set(a))
# Out:
# {'a', 1, 2, 3, 5}

# %%
b = {'a',1, 4, 8}
print(list(b))
# Out:
# ['a', 1, 4, 8]

# %%
print(tuple(b))
# Out:
# ('a', 1, 4, 8)

# %% [markdown]
# **Adding new items**

# %% [markdown]
# Since tuples are immutable, we can only add new items to a list or set. We have more alternatives when altering a list due to being ordered or indexed.
#
# For instance, append method adds an item at the end of a list. Since sets do not possess the concept of end or start, we cannot use the append method. For sets, the add method is used to add new items.

# %%
a = [1,2,3]
a.append(4)
print(a)
# Out:
# [1, 2, 3, 4]

# %%
b = {1,2,3}
b.add(4)
print(b)
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# **Insert an item to a list**

# %% [markdown]
# The insert function is also used to add an element to a list. However, it allows specifying the index of the new element. For instance, we can add a new element at the beginning of the list (index=0).

# %%
a = [1, 2, 3, 4, 5]
a.insert(0, 'a')
a
# Out:
# ['a', 1, 2, 3, 4, 5]

# %% [markdown]
# Since it requires an index, we cannot use the insert function on sets.

# %% [markdown]
# **Combining two objects**

# %% [markdown]
# There will be cases where we need add items of a type together. We have multiple options to combine objects of lists, tuples, and sets.
#
# The “+” operator can be used to add lists or tuples but not sets.

# %%
a = [1,2,3]
b = [11,32,1]
print(a + b)
# Out:
# [1, 2, 3, 11, 32, 1]

# %%
print(tuple(a) + tuple(b))
# Out:
# (1, 2, 3, 11, 32, 1)

# %% [markdown]
# We can use the union operator to combine two sets. The duplicate elements will be removed.

# %%
a = {1,2,3,4}
b = {1,5,6}
print(a.union(b))
# Out:
# {1, 2, 3, 4, 5, 6}

# %% [markdown]
# **Len and count**

# %% [markdown]
# The len function returns the length (i.e. number of items) of a collection. It works on lists, tuples, and sets.
#
# The count function can be used to count the number of occurrences of a specific element. It is only used with lists and tuples. Since sets do not contain any duplicate items, the count is 1 for all items.

# %%
a = [1,4,5,6,1]
b = (3,4)
c = {1,2,3,4}
print(len(a), len(b), len(c))
# Out:
# 5 2 4

# %%
print(a.count(1), b.count(3))
# Out:
# 2 1

# %% [markdown]
# **Questions**

# %% [markdown]
# 1) Which of the following is mutable?
#
#   a.list
#
#   b.string
#
#   c.set
#
#   d.tuple

# %% [markdown]
# 2) A list can contain _________ elements.
#
# a. Unlimited (depends on computer's memory)
# b. 10000
# c. 1 Million
# d. 10 Million

# %% [markdown]
# 3) What will be the output of the following code?
#
# nums=list({1:'one',2:'two'})
#
# print(nums)
#
# a. Syntax Error
#
# b. [1, 2]
#
# c. [‘one', ‘two']
#
# d. Runtime error

# %% [markdown]
# 4. Which of the following is true?
#
# a. List object can contain tuple as one of the items
#
# b. Tuple can contain a list as one of the items
#
# c. Both a and b are true
#
# d. Both a and b are false

# %% [markdown]
# 5. Which of following will result in error?
#
# a. tuple(‘1,2')
#
# b. tuple((1,2))
#
# c. tuple([1,2])
#
# d. tuple(1,2)
